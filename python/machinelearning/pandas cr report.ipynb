# %%
import pandas as pd

# %%
df = pd.read_excel('change_task.xlsx')
df
# Out:
#    Change request                                            Subject  \
# 0      CHG0050734  [Millicom] [MS1 AWS] - Revert back PPS and IdP...
# 1      CHG0049687  [TPA1][Production] AWS RDS db instance class t...
# 2      CHG0050704  [US][Staging][Morpheus] Enable External Calls ...
# 3      CHG0050684  [AWS][Staging][TPA1] Catalog-server - SoCu Cat...
# 4      CHG0049895  [US_TP1][RCN nDVR] Configure AUTHMIND_DRMProvi...
# 5      CHG0050738  [Prod] Migrate Midco DRM configuration to name...
# 6      CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 7      CHG0050718  [TPA1][Production] Update version of deployed ...
# 8      CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 9      CHG0050657  [AWS][TVE][Staging] TVE ABB, Armstrong, Blue R...
# 10     CHG0050622  US production - Refserver cutover to LV - Migr...
# 11     CHG0050766  [TPA1][Staging] - Replace IFTTT Cert Chain - R...
# 12     CHG0050762  [TPA1][Staging] - Replace Catalog-server Cert ...
#
# ...

# %%
df.columns
# Out:
# Index(['Change request', 'Subject', 'Scheduled start date',
#        'Scheduled end date', 'State'],
#       dtype='object')

# %%
# modified the dataframe to remove rows which doesn't met this condition
df = df[ df['State'] == 'Ready for Implementation' ]

# %%
df
# Out:
#   Change request                                            Subject  \
# 2     CHG0050704  [US][Staging][Morpheus] Enable External Calls ...
# 3     CHG0050684  [AWS][Staging][TPA1] Catalog-server - SoCu Cat...
# 4     CHG0049895  [US_TP1][RCN nDVR] Configure AUTHMIND_DRMProvi...
# 5     CHG0050738  [Prod] Migrate Midco DRM configuration to name...
# 6     CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 7     CHG0050718  [TPA1][Production] Update version of deployed ...
# 8     CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 9     CHG0050657  [AWS][TVE][Staging] TVE ABB, Armstrong, Blue R...
#
#   Scheduled start date  Scheduled end date                     State
# 2  2020-05-27 01:00:00 2020-05-27 05:00:00  Ready for Implementation
# 3  2020-05-27 03:00:00 2020-05-27 06:00:00  Ready for Implementation
# 4  2020-05-26 23:00:00 2020-05-27 05:00:00  Ready for Implementation
# 5  2020-05-26 22:00:00 2020-05-27 04:00:00  Ready for Implementation
# ...

# %%
# Sort based on the time
df.sort_values(by=['Scheduled start date'], inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#   Change request                                            Subject  \
# 5     CHG0050738  [Prod] Migrate Midco DRM configuration to name...
# 6     CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 8     CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 4     CHG0049895  [US_TP1][RCN nDVR] Configure AUTHMIND_DRMProvi...
# 9     CHG0050657  [AWS][TVE][Staging] TVE ABB, Armstrong, Blue R...
# 7     CHG0050718  [TPA1][Production] Update version of deployed ...
# 2     CHG0050704  [US][Staging][Morpheus] Enable External Calls ...
# 3     CHG0050684  [AWS][Staging][TPA1] Catalog-server - SoCu Cat...
#
#   Scheduled start date  Scheduled end date                     State
# 5  2020-05-26 22:00:00 2020-05-27 04:00:00  Ready for Implementation
# 6  2020-05-26 22:00:00 2020-05-27 04:00:00  Ready for Implementation
# 8  2020-05-26 22:00:00 2020-05-27 04:00:00  Ready for Implementation
# 4  2020-05-26 23:00:00 2020-05-27 05:00:00  Ready for Implementation
# ...

# %%
# Removed one column
df = df[['Change request','Subject','Scheduled start date','Scheduled end date']]
df
# Out:
#   Change request                                            Subject  \
# 5     CHG0050738  [Prod] Migrate Midco DRM configuration to name...
# 6     CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 8     CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 4     CHG0049895  [US_TP1][RCN nDVR] Configure AUTHMIND_DRMProvi...
# 9     CHG0050657  [AWS][TVE][Staging] TVE ABB, Armstrong, Blue R...
# 7     CHG0050718  [TPA1][Production] Update version of deployed ...
# 2     CHG0050704  [US][Staging][Morpheus] Enable External Calls ...
# 3     CHG0050684  [AWS][Staging][TPA1] Catalog-server - SoCu Cat...
#
#   Scheduled start date  Scheduled end date
# 5  2020-05-26 22:00:00 2020-05-27 04:00:00
# 6  2020-05-26 22:00:00 2020-05-27 04:00:00
# 8  2020-05-26 22:00:00 2020-05-27 04:00:00
# 4  2020-05-26 23:00:00 2020-05-27 05:00:00
# 9  2020-05-26 23:30:00 2020-05-27 05:00:00
# 7  2020-05-27 00:30:00 2020-05-27 04:30:00
# 2  2020-05-27 01:00:00 2020-05-27 05:00:00
# ...

# %%
# Dropping duplicates if any
df = df.drop_duplicates()
df
# Out:
#   Change request                                            Subject  \
# 5     CHG0050738  [Prod] Migrate Midco DRM configuration to name...
# 6     CHG0050424  US Production - Upgrade SSD firmware as per HP...
# 4     CHG0049895  [US_TP1][RCN nDVR] Configure AUTHMIND_DRMProvi...
# 9     CHG0050657  [AWS][TVE][Staging] TVE ABB, Armstrong, Blue R...
# 7     CHG0050718  [TPA1][Production] Update version of deployed ...
# 2     CHG0050704  [US][Staging][Morpheus] Enable External Calls ...
# 3     CHG0050684  [AWS][Staging][TPA1] Catalog-server - SoCu Cat...
#
#   Scheduled start date  Scheduled end date
# 5  2020-05-26 22:00:00 2020-05-27 04:00:00
# 6  2020-05-26 22:00:00 2020-05-27 04:00:00
# 4  2020-05-26 23:00:00 2020-05-27 05:00:00
# 9  2020-05-26 23:30:00 2020-05-27 05:00:00
# 7  2020-05-27 00:30:00 2020-05-27 04:30:00
# 2  2020-05-27 01:00:00 2020-05-27 05:00:00
# 3  2020-05-27 03:00:00 2020-05-27 06:00:00

# %%
# Write back to an excel
df.to_excel('changetask-20200527.xlsx')
