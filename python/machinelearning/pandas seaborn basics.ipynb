# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# TASKS:
#     Check the number of Clubs

# %%
club = df[['Name','Club']]

# %%
club = club.drop_duplicates()

# %%
club
# Out:
#                      Name                 Club
# 0                L. Messi         FC Barcelona
# 1       Cristiano Ronaldo             Juventus
# 2               Neymar Jr  Paris Saint-Germain
# 3                  De Gea    Manchester United
# 4            K. De Bruyne      Manchester City
# ...                   ...                  ...
# 18202        J. Lundstram      Crewe Alexandra
# 18203  N. Christoffersson       Trelleborgs FF
# 18204           B. Worman     Cambridge United
# 18205      D. Walker-Rice      Tranmere Rovers
# 18206           G. Nugent      Tranmere Rovers
#
# [18188 rows x 2 columns]

# %% [markdown]
# TASKS:
#     Plot a graph with players above Age 40 with renumeration

# %%
df = df[df['Age'] > 40]

# %%
df = df.sort_values(['Age'])

# %%
player = df[['Name','Age','Club','Release Clause']]

# %%
player.isnull()
# Out:
#         Name    Age   Club  Release Clause
# 1120   False  False   True            True
# 4228   False  False  False            True
# 7225   False  False  False           False
# 12192  False  False  False            True
# 15426  False  False  False           False
# 10545  False  False  False           False
# 17726  False  False  False            True
# 18183  False  False  False            True
# 4741   False  False  False           False

# %%
player.isnull().sum()
# Out:
# Name              0
# Age               0
# Club              1
# Release Clause    5
# dtype: int64

# %%
sns.set()

# %%
graph = sns.scatterplot(x='Age',y='Name',hue='Club',data=player)

# %%
graph = sns.relplot(x='Age',y='Name',hue='Club',data=player)
